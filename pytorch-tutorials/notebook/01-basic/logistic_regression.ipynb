# %% [markdown]
# ## logistic regression
# 使用MNIST数据测试torch的softmax回归

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms

# %%
# 超参数
inputs_size = 784
num_classes = 10
num_epochs = 5
batch_size = 100
learning_rate = 0.001

# %%
# MNIST dataset(images and labels) 
# 使用前面提到过的数据加载的输入pipeline
train_dataset = torchvision.datasets.MNIST(root="../data/", 
                                           train=True, 
                                           transform=transforms.ToTensor(), 
                                           download=True)

test_dataset = torchvision.datasets.MNIST(root="../data/", 
                                          train=False, 
                                          transform=transforms.ToTensor())

# Data Loader (input pipeline)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!

# %%
# logistic regression model, 和 线性回归一样，只是损失函数不一样
model = nn.Linear(inputs_size, num_classes)

# Loss and optimizer
loss_fun = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
# Train the model
total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = images.reshape(-1, 28*28)

        # Forward pass
        outputs = model(images)
        loss = loss_fun(outputs, labels)
        
        # Bachward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (i+1) % 100 == 0:
            print("Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}"
                  .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
# Out:
# Epoch [1/5], Step [10/600], Loss: 2.2774
# Epoch [1/5], Step [20/600], Loss: 2.2873
# Epoch [1/5], Step [30/600], Loss: 2.2662
# Epoch [1/5], Step [40/600], Loss: 2.2533
# Epoch [1/5], Step [50/600], Loss: 2.2736
# Epoch [1/5], Step [60/600], Loss: 2.2330
# Epoch [1/5], Step [70/600], Loss: 2.2637
# Epoch [1/5], Step [80/600], Loss: 2.2118
# Epoch [1/5], Step [90/600], Loss: 2.2073
# Epoch [1/5], Step [100/600], Loss: 2.1910
# Epoch [1/5], Step [110/600], Loss: 2.1687
# Epoch [1/5], Step [120/600], Loss: 2.1721
# Epoch [1/5], Step [130/600], Loss: 2.1683
# Epoch [1/5], Step [140/600], Loss: 2.1594
# Epoch [1/5], Step [150/600], Loss: 2.1782
# Epoch [1/5], Step [160/600], Loss: 2.1314
# Epoch [1/5], Step [170/600], Loss: 2.1589
# Epoch [1/5], Step [180/600], Loss: 2.0720
# Epoch [1/5], Step [190/600], Loss: 2.0847
# Epoch [1/5], Step [200/600], Loss: 2.1136
# Epoch [1/5], Step [210/600], Loss: 2.0925
# Epoch [1/5], Step [220/600], Loss: 2.1206
# Epoch [1/5], Step [230/600], Loss: 2.0412
# Epoch [1/5], Step [240/600], Loss: 2.0539
# Epoch [1/5], Step [250/600], Loss: 2.0642
# Epoch [1/5], Step [260/600], Loss: 2.0120
# Epoch [1/5], Step [270/600], Loss: 2.0038
# Epoch [1/5], Step [280/600], Loss: 2.0478
# Epoch [1/5], Step [290/600], Loss: 2.0124
# Epoch [1/5], Step [300/600], Loss: 2.0159
# Epoch [1/5], Step [310/600], Loss: 1.9824
# Epoch [1/5], Step [320/600], Loss: 2.0012
# Epoch [1/5], Step [330/600], Loss: 1.9827
# Epoch [1/5], Step [340/600], Loss: 1.9976
# Epoch [1/5], Step [350/600], Loss: 1.9619
# Epoch [1/5], Step [360/600], Loss: 1.9626
# Epoch [1/5], Step [370/600], Loss: 1.9752
# Epoch [1/5], Step [380/600], Loss: 1.9398
# Epoch [3/5], Step [270/600], Loss: 1.3302
# Epoch [3/5], Step [280/600], Loss: 1.3768
# Epoch [3/5], Step [290/600], Loss: 1.4111
# Epoch [3/5], Step [300/600], Loss: 1.3763
# Epoch [3/5], Step [310/600], Loss: 1.2803
# Epoch [3/5], Step [320/600], Loss: 1.3313
# Epoch [3/5], Step [330/600], Loss: 1.2897
# Epoch [3/5], Step [340/600], Loss: 1.3831
# Epoch [3/5], Step [350/600], Loss: 1.3408
# Epoch [3/5], Step [360/600], Loss: 1.3574
# Epoch [3/5], Step [370/600], Loss: 1.3715
# Epoch [3/5], Step [380/600], Loss: 1.3589
# Epoch [3/5], Step [390/600], Loss: 1.3452
# Epoch [3/5], Step [400/600], Loss: 1.3389
# Epoch [3/5], Step [410/600], Loss: 1.3610
# Epoch [3/5], Step [420/600], Loss: 1.3580
# Epoch [3/5], Step [430/600], Loss: 1.3700
# Epoch [3/5], Step [440/600], Loss: 1.3225
# Epoch [3/5], Step [450/600], Loss: 1.2619
# Epoch [3/5], Step [460/600], Loss: 1.2975
# Epoch [3/5], Step [470/600], Loss: 1.3427
# Epoch [3/5], Step [480/600], Loss: 1.4098
# Epoch [3/5], Step [490/600], Loss: 1.2701
# Epoch [3/5], Step [500/600], Loss: 1.2713
# Epoch [3/5], Step [510/600], Loss: 1.3638
# Epoch [3/5], Step [520/600], Loss: 1.2400
# Epoch [3/5], Step [530/600], Loss: 1.2889
# Epoch [3/5], Step [540/600], Loss: 1.2693
# Epoch [3/5], Step [550/600], Loss: 1.2515
# Epoch [3/5], Step [560/600], Loss: 1.2854
# Epoch [3/5], Step [570/600], Loss: 1.2409
# Epoch [3/5], Step [580/600], Loss: 1.2924
# Epoch [3/5], Step [590/600], Loss: 1.2689
# Epoch [3/5], Step [600/600], Loss: 1.1655
# Epoch [4/5], Step [10/600], Loss: 1.3784
# Epoch [4/5], Step [20/600], Loss: 1.2218
# Epoch [4/5], Step [30/600], Loss: 1.2408
# Epoch [4/5], Step [40/600], Loss: 1.2362
# Epoch [4/5], Step [50/600], Loss: 1.2161
# Epoch [4/5], Step [60/600], Loss: 1.1530
# Epoch [4/5], Step [70/600], Loss: 1.2633
# Epoch [4/5], Step [80/600], Loss: 1.2177
# Epoch [4/5], Step [90/600], Loss: 1.2305
# Epoch [4/5], Step [100/600], Loss: 1.2028
# Epoch [4/5], Step [110/600], Loss: 1.1662
# Epoch [4/5], Step [120/600], Loss: 1.1863
# Epoch [4/5], Step [130/600], Loss: 1.2548
# Epoch [4/5], Step [140/600], Loss: 1.2744
# Epoch [4/5], Step [150/600], Loss: 1.2502
# Epoch [4/5], Step [160/600], Loss: 1.2144
# Epoch [4/5], Step [170/600], Loss: 1.2989
# Epoch [4/5], Step [180/600], Loss: 1.1603
# Epoch [4/5], Step [190/600], Loss: 1.1577
# Epoch [4/5], Step [200/600], Loss: 1.2067
# Epoch [4/5], Step [210/600], Loss: 1.1232
# Epoch [4/5], Step [220/600], Loss: 1.1664
# Epoch [4/5], Step [230/600], Loss: 1.2075
# Epoch [4/5], Step [240/600], Loss: 1.1139
# Epoch [4/5], Step [250/600], Loss: 1.1802
# Epoch [4/5], Step [260/600], Loss: 1.0911
# Epoch [4/5], Step [270/600], Loss: 1.1130
# Epoch [4/5], Step [280/600], Loss: 1.1979
# Epoch [4/5], Step [290/600], Loss: 1.1573
# Epoch [4/5], Step [300/600], Loss: 1.1303
# Epoch [4/5], Step [310/600], Loss: 1.1707
# Epoch [4/5], Step [320/600], Loss: 1.1301
# Epoch [4/5], Step [330/600], Loss: 1.1954
# Epoch [4/5], Step [340/600], Loss: 1.1498
# Epoch [4/5], Step [350/600], Loss: 1.1477
# Epoch [4/5], Step [360/600], Loss: 1.2836
# Epoch [4/5], Step [370/600], Loss: 1.1875
# Epoch [4/5], Step [380/600], Loss: 1.1793
# Epoch [4/5], Step [390/600], Loss: 1.1577
# Epoch [4/5], Step [400/600], Loss: 1.0778
# Epoch [4/5], Step [410/600], Loss: 1.0881
# Epoch [4/5], Step [420/600], Loss: 1.0299
# Epoch [4/5], Step [430/600], Loss: 1.1454
# Epoch [4/5], Step [440/600], Loss: 1.0166
# Epoch [4/5], Step [450/600], Loss: 1.1250
# Epoch [4/5], Step [460/600], Loss: 1.1307
# Epoch [4/5], Step [470/600], Loss: 1.1012
# Epoch [4/5], Step [480/600], Loss: 1.2326
# Epoch [4/5], Step [490/600], Loss: 1.1417
# Epoch [4/5], Step [500/600], Loss: 1.1272
# Epoch [4/5], Step [510/600], Loss: 1.0940
# Epoch [4/5], Step [520/600], Loss: 1.0963
# Epoch [4/5], Step [530/600], Loss: 1.0510
# Epoch [4/5], Step [540/600], Loss: 1.1844
# Epoch [4/5], Step [550/600], Loss: 1.0838
# Epoch [4/5], Step [560/600], Loss: 1.0679
# Epoch [4/5], Step [570/600], Loss: 1.1843
# Epoch [4/5], Step [580/600], Loss: 1.1237
# Epoch [4/5], Step [590/600], Loss: 1.1110
# Epoch [4/5], Step [600/600], Loss: 1.1252
# Epoch [5/5], Step [10/600], Loss: 1.0650
# Epoch [5/5], Step [20/600], Loss: 1.1331
# Epoch [5/5], Step [30/600], Loss: 1.1261
# Epoch [5/5], Step [40/600], Loss: 1.1265
# Epoch [5/5], Step [50/600], Loss: 1.1131
# Epoch [5/5], Step [60/600], Loss: 1.0501
# Epoch [5/5], Step [70/600], Loss: 1.0423
# Epoch [5/5], Step [80/600], Loss: 1.0265
# Epoch [5/5], Step [90/600], Loss: 1.0344
# Epoch [5/5], Step [100/600], Loss: 1.0692
# Epoch [5/5], Step [110/600], Loss: 1.0899
# Epoch [5/5], Step [120/600], Loss: 1.1228
# Epoch [5/5], Step [130/600], Loss: 1.0027
# Epoch [5/5], Step [140/600], Loss: 1.1360
# Epoch [5/5], Step [150/600], Loss: 1.1142
# Epoch [5/5], Step [160/600], Loss: 1.0507
# Epoch [5/5], Step [170/600], Loss: 1.0487
# Epoch [5/5], Step [180/600], Loss: 1.0344
# Epoch [5/5], Step [190/600], Loss: 1.0505
# Epoch [5/5], Step [200/600], Loss: 1.0729
# Epoch [5/5], Step [210/600], Loss: 1.1397
# Epoch [5/5], Step [220/600], Loss: 1.0956
# Epoch [5/5], Step [230/600], Loss: 1.1502
# Epoch [5/5], Step [240/600], Loss: 1.0002
# Epoch [5/5], Step [250/600], Loss: 1.0254
# Epoch [5/5], Step [260/600], Loss: 1.0153
# Epoch [5/5], Step [270/600], Loss: 1.1008
# Epoch [5/5], Step [280/600], Loss: 1.0054
# Epoch [5/5], Step [290/600], Loss: 1.1022
# Epoch [5/5], Step [300/600], Loss: 1.0422
# Epoch [5/5], Step [310/600], Loss: 1.1114
# Epoch [5/5], Step [320/600], Loss: 1.0325
# Epoch [5/5], Step [330/600], Loss: 0.9908
# Epoch [5/5], Step [340/600], Loss: 1.0418
# Epoch [5/5], Step [350/600], Loss: 1.0327
# Epoch [5/5], Step [360/600], Loss: 1.0912
# Epoch [5/5], Step [370/600], Loss: 1.0723
# Epoch [5/5], Step [380/600], Loss: 0.9630
# Epoch [5/5], Step [390/600], Loss: 1.0296
# Epoch [5/5], Step [400/600], Loss: 1.1266
# Epoch [5/5], Step [410/600], Loss: 0.9017
# Epoch [5/5], Step [420/600], Loss: 1.1082
# Epoch [5/5], Step [430/600], Loss: 1.0780
# Epoch [5/5], Step [440/600], Loss: 1.0493
# Epoch [5/5], Step [450/600], Loss: 1.0121
# Epoch [5/5], Step [460/600], Loss: 1.0364
# Epoch [5/5], Step [470/600], Loss: 0.9381
# Epoch [5/5], Step [480/600], Loss: 0.8934
# Epoch [5/5], Step [490/600], Loss: 1.0100
# Epoch [5/5], Step [500/600], Loss: 1.0062
# Epoch [5/5], Step [510/600], Loss: 1.0741
# Epoch [5/5], Step [520/600], Loss: 1.0432
# Epoch [5/5], Step [530/600], Loss: 1.0043
# Epoch [5/5], Step [540/600], Loss: 1.0854
# Epoch [5/5], Step [550/600], Loss: 1.0065
# Epoch [5/5], Step [560/600], Loss: 0.9589
# Epoch [5/5], Step [570/600], Loss: 1.0263
# Epoch [5/5], Step [580/600], Loss: 0.9293
# Epoch [5/5], Step [590/600], Loss: 0.9779
# Epoch [5/5], Step [600/600], Loss: 0.9866

# %%
# Test the model
# In test phase, we don't need to compute gradients (for memory efficiency)
with torch.no_grad():
    corrent = 0
    total = 0
    for images, labels in test_loader:
        images = images.reshape(-1, 28*28)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        corrent += (predicted == labels).sum()
    print("Accuracy of the model on the 10000 test iamges: {} %".format(100 * corrent / total))
# Out:
# Accuracy of the model on the 10000 test iamges: 82 %

# %%
# Save the model checkpoint
torch.save(model.state_dict(), "../model/lr_model.ckpt")
